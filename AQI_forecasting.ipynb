# %% [markdown]
# <a href="https://colab.research.google.com/github/Amna-Qamar/AQI-Forecast/blob/main/AQI_forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests pandas numpy scikit-learn tensorflow feast[aws] pyarrow shap streamlit==1.24.1 matplotlib seaborn
